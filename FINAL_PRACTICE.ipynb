# %% [markdown]
# <a href="https://colab.research.google.com/github/7illz/Data-Structure/blob/main/FINAL_PRACTICE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# Run this cell first

# %%
class Node:
  def __init__(self, elem, next = None):
    self.elem, self.next = elem, next

def create_linked_list(arr):
  head = Node(arr[0])
  tail = head
  for i in arr[1:]:
    new_node = Node(i)
    tail.next = new_node
    tail = new_node
  return head

def count(head):
  count = 0
  while head != None:
    count += 1
    head = head.next
  return count

def print_linked_list(head):
  while head != None:
    print(head.elem, end = '-> ')
    head = head.next
  print('None')
  print()

# %% [markdown]
# #TASK 1
# > You can use Dictionary, Set and membership operator (in/not in) for this task. Membership Operator takes constant time in these unordered collections.
#
#
#
# However,
#
#
# >  ***DO NOT USE*** Membership Operator in List, String for this task.
#
# > You can traverse the array ***ONLY ONCE*** (i.e. no nested loop).

# %%
#Do by yourself
def nerdy_run(path,k):
  dic={}
  for i in range(len(path)):

    if path[i] not in dic.keys():

        dic[path[i]]=i

    else:
        if i-dic[path[i]]<=k:
            return path[i]

  return None

# %%
def main():

  path = [6,7,8,9,5,9]
  k = 3
  result = nerdy_run(path,k)
  unittest.output_test(result, 9)
  print(f'Duplicate value within range {k} is: {result}') #Duplicate value within range 3 is: 9

  print('===================================')
  path = [6,7,8,9,5,6]
  k = 4
  result = nerdy_run(path,k)
  unittest.output_test(result, None)
  print(f'Duplicate value within range {k} is: {result}') #Duplicate value within range 4 is: None

  print('===================================')
  path = [0.21,1.21,4.67,0.21,0.45,1.9]
  k = 7
  result = nerdy_run(path,k)
  unittest.output_test(result, 0.21)
  print(f'Duplicate value within range {k} is: {result}') #Duplicate value within range 7 is: 0.21


if __name__ == "__main__":
  main()
# Out:
# Accepted
# Duplicate value within range 3 is: 9
# ...
# Accepted
# Duplicate value within range 4 is: None
# ...
# Accepted
# Duplicate value within range 7 is: 0.21

# %% [markdown]
# #TASK 2
# Complete the following methods:
#
# >  __hash_function()
#
# > search_hashtable()

# %%
class Node_pair:
  def __init__(self, key, value, next = None):
    self.key, self.value, self.next = key, value, next


class Hashtable:
  def __init__(self, size):
    self.ht = [None]*size


  def insert(self, s):
    if self.search_hashtable(s) == 'Found':
      print(s,'Already Inserted. Cannot reinsert.')
      print('===============================')
      return
    hashed_index = self.__hash_function(s[0])
    pair = Node_pair(s[0], s[1])
    if self.ht[hashed_index] == None:
      self.ht[hashed_index] = pair
    else:
      pair.next = self.ht[hashed_index]
      self.ht[hashed_index] = pair


  def create_from_array(self, arr):
    for i in arr:
      self.insert(i)

  def print_hashtable(self):
    idx = 0
    for i in self.ht:
      print(idx, ':', end = ' ')
      head = i
      while head != None:
        print(f'(key: {head.key}, value: {head.value})', end = '-->')
        head = head.next
      print('None')
      print()
      idx += 1


  #Do by yourself
  def __hash_function(self, s):

    if len(s)%2!=0:

        s=s+'N'

    sum=0

    for i in range(0,len(s)-1,2):

        var=str(ord(s[i])) + str(ord(s[i+1]))
        sum+=int(var)

    index=sum%len(self.ht)
    return index


  #Do by yourself
  def search_hashtable(self, s):
    s=s[0]
    index=self.__hash_function(s)

    if self.ht[index]==None:
        return 'Not found'

    else:
        temp=self.ht[index]
        while temp!=None:
            if temp.key==s:
                return 'Found'

            temp=temp.next
        return 'Not found'

# %%
arr = [('Colt', 360), ('Cordelius', 730), ('Shelly', 300), ('Doug', 1200), ('Emz', 520), ('Bo', 580)]
ht = Hashtable(5)
ht.create_from_array(arr)
ht.print_hashtable()

print('======================')
result = ht.search_hashtable(('Doug', 1200))
unittest.output_test(result, 'Found')
print(f'(Doug, 1200) {result}')

print('======================')
ht.insert(('Doug', 1200))
ht.print_hashtable()

print('======================')
result = ht.search_hashtable(('Edgar', 320))
unittest.output_test(result, 'Not Found')
print(f'(Edgar, 320) {result}')

print('======================')
ht.insert(('Edgar', 320))
ht.print_hashtable()

print('======================')
result = ht.search_hashtable(('Edgar', 320))
unittest.output_test(result, 'Found')
print(f'(Edgar, 320) {result}')
# Out:
# 0 : None
#
# 1 : (key: Bo, value: 580)-->None
#
# 2 : (key: Emz, value: 520)-->(key: Colt, value: 360)-->None
#
# 3 : (key: Shelly, value: 300)-->None
#
# 4 : (key: Doug, value: 1200)-->(key: Cordelius, value: 730)-->None
#
# ...
# Accepted
# (Doug, 1200) Found
# ...
# ('Doug', 1200) Already Inserted. Cannot reinsert.
# ...
# 0 : None
#
# 1 : (key: Bo, value: 580)-->None
#
# 2 : (key: Emz, value: 520)-->(key: Colt, value: 360)-->None
#
# 3 : (key: Shelly, value: 300)-->None
#
# 4 : (key: Doug, value: 1200)-->(key: Cordelius, value: 730)-->None
#
# ...
# Accepted
# (Edgar, 320) Not found
# ...
# 0 : (key: Edgar, value: 320)-->None
#
# 1 : (key: Bo, value: 580)-->None
#
# 2 : (key: Emz, value: 520)-->(key: Colt, value: 360)-->None
#
# 3 : (key: Shelly, value: 300)-->None
#
# 4 : (key: Doug, value: 1200)-->(key: Cordelius, value: 730)-->None
#
# ...
# Accepted
# (Edgar, 320) Found

# %% [markdown]
# #TASK 3
# Complete the following methods:
#
#
#
# > create_layered_hashtable()
#
# > search_element()

# %%
# class Layered_Hashtable:
#   def __init__(self, express_array_size):
#     self.express_array = [None] * express_array_size

#   def print_express_lane(self):
#     for i in self.express_array:
#       print(i.elem, end = ' '*10)
#     print()

#   def print_layered_hashtable(self):
#     print('Express Lane is:')
#     self.print_express_lane()

#     for i in range (len(self.express_array)-1):
#       node = self.express_array[i]
#       next_node = self.express_array[i+1]
#       print(f'Normal Lane Nodes between Express Lane Node {node.elem} and Express Lane Node {next_node.elem} are: ')
#       while node != next_node:
#         print(node.elem, end = '->')
#         node = node.next
#       print()

#     print(f'Normal Lane Nodes ending in the Express Lane Node: {node.elem}')

#   #DO IT YOURSELF
#   def create_layered_hashtable(self, linked_list_head):
#     pass

#   #DO IT YOURSELF
#   def search_element(self,k):
#     pass
#     return None

# %%
# arr = [4,6,9,18,25,37,62,67,79,84]
# head = create_linked_list(arr)
# express_array_size = 4

# layered_ht = Layered_Hashtable(express_array_size)
# layered_ht.create_layered_hashtable(head)
# layered_ht.print_layered_hashtable()

# print('==========1===========')
# result = layered_ht.search_element(67)
# unittest.output_test(result, 'Found')
# print(f'67 {result}') #67 Found

# print('==========2===========')
# result = layered_ht.search_element(84)
# unittest.output_test(result, 'Found')
# print(f'84 {result}') #84 Found

# print('==========3===========')
# result = layered_ht.search_element(1)
# unittest.output_test(result, 'Not Found')
# print(f'1 {result}') #1 Not Found

# print('==========4===========')
# result = layered_ht.search_element(92)
# unittest.output_test(result, 'Not Found')
# print(f'92 {result}') #92 Not Found

# print('==========5===========')
# result = layered_ht.search_element(41)
# unittest.output_test(result, 'Not Found')
# print(f'41 {result}') #41 Not Found

# %%
class Node_pair:
  def __init__(self, key, value, next = None):
    self.key, self.value, self.next = key, value, next


class Hashtable:
  def __init__(self, size):
    self.ht = [None]*size


  def insert(self, s):
    if self.search_hashtable(s) == 'Found':
      print(s,'Already Inserted. Cannot reinsert.')
      print('===============================')
      return
    hashed_index = self.__hash_function(s[0])
    pair = Node_pair(s[0], s[1])
    if self.ht[hashed_index] == None:
      self.ht[hashed_index] = pair
    else:
      pair.next = self.ht[hashed_index]
      self.ht[hashed_index] = pair


  def create_from_array(self, arr):
    for i in arr:
      self.insert(i)

  def print_hashtable(self):
    idx = 0
    for i in self.ht:
      print(idx, ':', end = ' ')
      head = i
      while head != None:
        print(f'(key: {head.key}, value: {head.value})', end = '-->')
        head = head.next
      print('None')
      print()
      idx += 1


  #Do by yourself
  def __hash_function(self, s):
    idx=s
    index=(s**2+3)%6
    return index


  #Do by yourself
  def search_hashtable(self, s):
    idx= self.__hash_function(s[0])
    if self.ht[idx]==None:
        return "Not Found"
    else:
        head=self.ht[idx]
        while head!=None:
            if head.key==s[0] and head.value==s[1]:
                return 'Found'
            else:
                head=head.next
        return 'Not Found'

  def delete(self,k):
    idx= self.__hash_function(k)

    temp=self.ht[idx]

    if temp.key==None:
        return self.ht

    else:
        if self.ht[idx].key==k:
            self.ht[idx]=self.ht[idx].next
            return self.ht

        else:
            var=temp.next
            while temp!=None:
                if var.key==k:
                    temp.next=var.next
                    return self.ht
                var=var.next
                temp=temp.next

# %%
arr = [(2,'Abid'),(4,"Rafi"),(6,"Karim"),(3,"Chitra"),(8,"Nilu")]
h = Hashtable(5)
h.create_from_array(arr)
h.print_hashtable()
h.delete(2)
h.print_hashtable()
# Out:
# 0 : (key: 3, value: Chitra)-->None
#
# 1 : (key: 8, value: Nilu)-->(key: 4, value: Rafi)-->(key: 2, value: Abid)-->None
#
# 2 : None
#
# 3 : (key: 6, value: Karim)-->None
#
# 4 : None
#
# 0 : (key: 3, value: Chitra)-->None
#
# 1 : (key: 8, value: Nilu)-->(key: 4, value: Rafi)-->None
#
# 2 : None
#
# 3 : (key: 6, value: Karim)-->None
#
# 4 : None

# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.right = None
    self.left = None

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])

# %%
#WRITE THE FUNCTION and DRIVER CODE BY YOURSELF
###Driver Code

def sumTree(root,i=0,sum=0):

    if root==None:
        return 0

    if root.right==None and root.left==None :
        return root.elem

    sum+=sumTree(root.left,i+1)
    sum+=sumTree(root.right,i+1)

    if i!=0:
        sum+=root.elem
        return sum
    else:
        if sum==root.elem:
            return True
        else:
            return False

r1=tree_construction([None, 26, 10, 3, 4, 6, None, 3, None, None, None, None,None,None,None,None])


sumTree(r1)
# Out:
# True

# %%
#WRITE THE FUNCTION BY YOURSELF
def all(root,level=0):
    if root ==None:
        return 0

    if level%2==0:
        sum=-root.elem

    else:
        sum=root.elem

    left=all(root.left,level+1)
    right=all(root.right,level+1)
    return left+right+sum


#DRIVER CODE
root = BTNode(1)
n2 = BTNode(2)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(5)
n6 = BTNode(6)
n7 = BTNode(7)
n8 = BTNode(8)
root.left = n2
root.right = n3

n2.left = n4
n3.left = n5
n3.right = n6

n5.left = n7
n5.right = n8
all(root)
# Out:
# 4

# %%
##6
def helper(arr):

    mid=len(arr)//2


    if arr[0:mid]==arr[len(arr)-1:mid:-1]:

        return True

    else:
        return False

def check(root):
    var=isSymmetric(root)
    return helper(var)

def isSymmetric(root,a1=[]):

    if root==None:
        return a1

    isSymmetric(root.left,a1)

    a1.append(root.elem)

    return isSymmetric(root.right,a1)

r5=tree_construction([None, 1, 2, 2, 3, 4, 4,3])
check(r5)
# Out:
# True

# %%
#
def hasPathSum(root,k,sum=0):
    if root==None:
        return False

    sum+=root.elem

    if root.left==None and root.right==None:
        if k!=sum:
            sum-=root.elem
            return False
        else:
            return True

    return hasPathSum(root.left,k,sum) or hasPathSum(root.left,k,sum)

r=tree_construction([None, 5, 4, 8, 11,None,13,17,7,2,None,None,None,1])

hasPathSum(r,22)
# Out:
# False

# %%
def helper(root):

    if root==None:
        return 0

    if root.left==None and root.right==None:
        return root .elem

    return root.elem + helper(root.left) +helper(root.right)


def summation(root,level=0,sum=0):
    if root==None:
        return 0

    if root.left==None and root.right==None:
        return root.elem

    sum+=summation(root.left,level+1)

    if level==0:
        var=helper(root.right)
        final=sum-var
        return final


    sum+=summation(root.right,level+1)

    if level!=0:
        sum+=root.elem
        return sum




r=tree_construction([None, 71, 27, 62, 80,75,41,3,87,56,None,None,None,None,19,89])
summation(r)
# Out:
# 111

# %%
def helper(root):

    if root==None:
        return 0

    # if root.left==None and root.right==None:
    #     return root .elem

    return root.elem + helper(root.left) +helper(root.right)

def summation(root):
    if root==None:
        return 0

    left=helper(root.left)
    right=helper(root.right)
    return left-right


r=tree_construction([None, 71, 27, 62, 80,75,41,3,87,56,None,None,None,None,19,89])
summation(r)
# Out:
# 111

# %%
#Input 2
root2 = BTNode(2)
node12 = BTNode(4)
node13 = BTNode(5)
node14 = BTNode(9)
node15 = BTNode(11)
node16 = BTNode(98)
node17 = BTNode(62)
node18 = BTNode(17)
node19 = BTNode(15)
node20 = BTNode(45)
node21 = BTNode(8)

root2.left = node12
root2.right = node13

node12.left = node14

node13.left = node15
node13.right = node16

node14.left = node17
node14.right = node18

node18.left = node19
node18.right = node20

node20.right = node21


#Input 1
root1 = BTNode(9)
node2 = BTNode(4)
node3 = BTNode(5)
node4 = BTNode(18)
node5 = BTNode(14)
node6 = BTNode(3)
node7 = BTNode(54)
node8 = BTNode(12)
node9 = BTNode(8)
node10 = BTNode(91)
node11 = BTNode(56)

root1.left = node2
root1.right = node3

node2.left = node4

node3.left = node5
node3.right = node6

node4.left = node7
node4.right = node8

node5.left = node9

node8.left = node10
node8.right = node11

def helper(root,level,sum=0):
    if root==None:
        return 0

    if root.right==None and root.left==None:
        var=root.elem%level
        return var

    return helper(root.left,level+1) + helper(root.right,level+1) + root.elem%level

def sumtree(root,level=0):
    if root==None:
        return 0

    left=helper(root.left,level+1)
    right=helper(root.right,level+1)

    return left+right+root.elem


sumtree(root1)
# Out:
# 15

# %%
r=tree_construction([None, 5, 4, 8, 11,None,13,17,7,2,None,None,None,1])
def hasPathSum(root,target,sum=0,level=0,var=False):
    if root==None:
        return 0

    sum+=root.elem

    if root.left==None and root.right==None:
        if sum==target:
            var=True
            return var
        else:
            sum-=root.elem
            var=False
            return var

    return hasPathSum(root.left,target,sum,level+1,var=True) or hasPathSum(root.right,target,sum,level+1,var=True)







hasPathSum(r,22)
# Out:
# True

# %%
### 4
var= tree_construction([None, 10,7,3,2,5,1,2,None])
def sum_check(root,sum,level=0,flag=True):
    if root==None:
        return 0

    if root.left==None and root.right==None:
        return root.elem

    sum+=sum_check(root.left,sum,level+1,flag)
    sum+=sum_check(root.left,sum,level+1,flag)

    if i!=0:\


sum_check(var)
# Out:
#   File "/tmp/ipykernel_12062/836057180.py", line 16
#     sum_check(var)
#                   ^
# IndentationError: expected an indented block after 'if' statement on line 13

# %%
#### 8
var= tree_construction([None, 1,2,3,4,5,None,None,7])

def ancestors(root,k,flag=False):
    if root==None:
        return flag

    var=root.elem

    left=ancestors(root.left,k,flag)

    if root.elem==k:
        flag=True

    if flag==True:

        print(var)
        return flag

    if left==False:
        return ancestors(root.right,k,flag)

ancestors(var,7)
