# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.right = None
    self.left = None

# %%
def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %% [markdown]
# Task 1

# %%
def convert_mirror(root):

  if root==None:
    return

  tree=BTNode(root.elem)
  tree.left=convert_mirror(root.right)
  tree.right=convert_mirror(root.left)

  return tree



#DRIVER CODE
root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  40 20 60 10 30
print()

root2 = convert_mirror(root)
print('Mirrored Tree Inorder Traversal: ', end = ' ')
inorder(root2) #Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# Task 2

# %%
def smallest_level(root,level=0,dic={}):

    if root==None:
        return

    if level not in dic:
        dic[level]=root.elem

    else:
        if root.elem<dic[level]:
            dic[level]=root.elem

    smallest_level(root.left,level+1,dic)
    smallest_level(root.right,level+1,dic)
    return dic

#DRIVER CODE
root = tree_construction([None, 4,9,2,3,-5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 5 4 2 7
print()
print('Level Wise Smallest Value: ', end = ' ')
print(smallest_level(root)) #Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}
# Out:
# Given Tree Inorder Traversal:  3 9 -5 4 2 7
# Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}

# %% [markdown]
# Task 3

# %%
def inorder_predecessor(root, x):

    if root==None:
        return None

    elif root.elem >= x.elem:
       return  inorder_predecessor(root.left,x)

    elif root.elem < x.elem:

        store=inorder_predecessor(root.right,x)

        if store==None:
            return root
        else:
            return store


#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = root
print(f'Inorder predecessor of node {x.elem}: {inorder_predecessor(root, x).elem}') #Inorder predecessor of node 20: 14
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# Inorder predecessor of node 20: 14

# %% [markdown]
# Task 4

# %%
def LCA(root, x, y):

    if root.elem>x and root.elem>y:
        return LCA(root.left,x,y)


    if root.elem<x and root.elem<y:
        return LCA(root.right,x,y)

    else:
        return root.elem



root=tree_construction([None, 15, 10, 25, 8, 12, 20, 30, 6, 9, None, None, 18, 22, None, None])
# inorder(root)
#DRIVER CODE
#Write by yourself from the given tree
#check all the sample inputs given
print(LCA(root,6,12))
print(LCA(root,20,6))
print(LCA(root,18,22))
print(LCA(root,20,25))
print(LCA(root,10,12))
# Out:
# 10
# 15
# 20
# 25
# 10

# %% [markdown]
# BONUS TASK 1

# %%
#WRITE THE FUNCTION and DRIVER CODE BY YOURSELF
def calculate_sum(root):
    if root is None:
        return 0
    return calculate_sum(root.left) + root.elem + calculate_sum(root.right)

def sumTree(root):
    if root is None:
        return True

    if root.left is root.right is None:
        return True

    if root.elem != calculate_sum(root.right) + calculate_sum(root.left):
        return False

    return sumTree(root.left) and sumTree(root.right)

###Driver Code

r1=tree_construction([None, 26, 10, 3, 4, 6, None, 3, None, None, None, None,None,None,None,None])


sumTree(r1)
# Out:
# True

# %% [markdown]
# Bonus Task 2

# %%
#WRITE THE FUNCTION BY YOURSELF

def oddEven(root,level=0,sum=0):

    if root==None:
        return 0

    if root.left==root.right==None:
        if level%2==0:
            return -root.elem

        else:
            return root.elem

    sum+=oddEven(root.left,level+1,0)
    sum+=oddEven(root.right,level+1,0)

    if level!=0:
        if level%2!=0:
            return sum+root.elem

        else:

            sum-root.elem
    return sum-root.elem


#DRIVER CODE
root = BTNode(1)
n2 = BTNode(2)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(5)
n6 = BTNode(6)
n7 = BTNode(7)
n8 = BTNode(8)
root.left = n2
root.right = n3

n2.left = n4
n3.left = n5
n3.right = n6

n5.left = n7
n5.right = n8
print(oddEven(root))
# Out:
# 4
